# %%
import sys 
import glob
from time import sleep
from io import StringIO
from collections import defaultdict
from typing import Union
import entrezpy.conduit



# vseek imports
sys.path.append("../")
import vseek.common.vseek_paths as vsp
from vseek.common.loader import load_bat_virus_data
from vseek.apis.ncbi import get_viral_genomes, get_viral_genes
from vseek.common.checks import genome_db_exist
from vseek.common.io_files import get_genome_genes_paths, get_viral_genome_fasta_paths, save_genes, clean_all_genes

# %%
# loading bat-virus data
bat_vir_df = load_bat_virus_data()
bat_vir_df = bat_vir_df.drop("Unnamed: 0", axis="columns")
all_accessions = bat_vir_df["Representative"].tolist()

bat_vir_df.head()
# Out:
#   Representative   Host                 Taxonomy name Segment name  \
# 0      NC_001348  human      Human alphaherpesvirus 3      segment
# 1      NC_001352  human   Human papillomavirus type 2      segment
# 2      NC_001354  human  Human papillomavirus type 41      segment
# 3      NC_001356  human  Human papillomavirus type 1a      segment
# 4      NC_001430  human               Enterovirus D68      segment
#
#              family                genus
# 0     Herpesviridae       Varicellovirus
# 1  Papillomaviridae  Alphapapillomavirus
# 2  Papillomaviridae     Nupapillomavirus
# 3  Papillomaviridae     Mupapillomavirus
# 4    Picornaviridae          Enterovirus

# %%
get_viral_genes(email="erikishere3@gmail.com", accession=all_accessions)
# Out:
# Downloading viral genes metadata
# Checking if genome database exists ...
# Database exists! Checking for missing gene data files
# Warning there are some missing genomes
# > Requesting NC_035211 genes ...
# > Requesting NC_001943 genes ...
# > Requesting NC_012776 genes ...
# > Requesting NC_017995 genes ...
# > Requesting NC_009539 genes ...
# > Requesting NC_026161 genes ...
# > Requesting NC_038351 genes ...
# > Requesting NC_022788 genes ...
# > Requesting NC_001526 genes ...
# > Requesting NC_001676 genes ...
# > Requesting NC_014086 genes ...
# > Requesting NC_014361 genes ...
# > Requesting NC_020106 genes ...
# > Requesting NC_038728 genes ...
# > Requesting NC_055331 genes ...
# > Requesting NC_006317 genes ...
# > Requesting NC_038605 genes ...
# > Requesting NC_038600 genes ...
# > Requesting NC_001586 genes ...
# > Requesting NC_038602 genes ...
# > Requesting NC_038350 genes ...
# > Requesting NC_039061 genes ...
# > Requesting NC_055339 genes ...
# > Requesting NC_010562 genes ...
# > Requesting NC_001722 genes ...
# > Requesting NC_038415 genes ...
# > Requesting NC_034506 genes ...
# > Requesting NC_038357 genes ...
# > Requesting NC_005831 genes ...
# > Requesting NC_055341 genes ...
# > Requesting NC_036877 genes ...
# > Requesting NC_038607 genes ...
# > Requesting NC_040619 genes ...
# > Requesting NC_038596 genes ...
# > Requesting NC_040803 genes ...
# > Requesting NC_024118 genes ...
# > Requesting NC_025727 genes ...
# > Requesting NC_030448 genes ...
# > Requesting NC_035213 genes ...
# > Requesting NC_038355 genes ...
# > Requesting NC_040550 genes ...
# > Requesting NC_039025 genes ...
# > Requesting NC_038283 genes ...
# > Requesting NC_038604 genes ...
# > Requesting NC_038597 genes ...
# > Requesting NC_043067 genes ...
# > Requesting NC_001664 genes ...
# > Requesting NC_055328 genes ...
# > Requesting NC_009225 genes ...
# > Requesting NC_007027 genes ...
# > Requesting NC_001699 genes ...
# > Requesting NC_014954 genes ...
# > Requesting NC_038356 genes ...
# > Requesting NC_012802 genes ...
# > Requesting NC_021928 genes ...
# > Requesting NC_038312 genes ...
# > Requesting NC_038525 genes ...
# > Requesting NC_024694 genes ...
# > Requesting NC_039024 genes ...
# > Requesting NC_055327 genes ...
# > Requesting NC_001690 genes ...
# > Requesting NC_006437 genes ...
# > Requesting NC_038346 genes ...
# > Requesting NC_001694 genes ...
# > Requesting NC_005134 genes ...
# > Requesting NC_014076 genes ...
# > Requesting NC_018102 genes ...
# > Requesting NC_038359 genes ...
# > Requesting NC_038608 genes ...
# > Requesting NC_014074 genes ...
# > Requesting NC_010563 genes ...
# > Requesting NC_016155 genes ...
# > Requesting NC_022892 genes ...
# > Requesting NC_034253 genes ...
# > Requesting NC_038417 genes ...
# > Requesting NC_001716 genes ...
# > Requesting NC_034443 genes ...
# > Requesting NC_023874 genes ...
# > Requesting NC_040620 genes ...
# > Requesting NC_038601 genes ...
# > Requesting NC_014093 genes ...
# > Requesting NC_043445 genes ...
# > Requesting NC_034486 genes ...
# > Requesting NC_022095 genes ...
# > Requesting NC_017997 genes ...
# > Requesting NC_027779 genes ...
# > Requesting NC_009889 genes ...
# > Requesting NC_038416 genes ...
# > Requesting NC_038595 genes ...
# > Requesting NC_055332 genes ...
# > Requesting NC_014088 genes ...
# > Requesting NC_038613 genes ...
# > Requesting NC_038524 genes ...
# > Requesting NC_001595 genes ...
# > Requesting NC_019026 genes ...
# > Requesting NC_055343 genes ...
# > Requesting NC_040688 genes ...
# > Requesting NC_038609 genes ...
# > Requesting NC_055342 genes ...
# > Requesting NC_012486 genes ...
# > Requesting NC_038610 genes ...
# > Requesting NC_006433 genes ...
# > Requesting NC_014094 genes ...
# > Requesting NC_055344 genes ...
# > Requesting NC_038353 genes ...
# > Requesting NC_012777 genes ...
# > Requesting NC_055330 genes ...
# > Requesting NC_010277 genes ...
# > Requesting NC_040691 genes ...
# > Requesting NC_034261 genes ...
# > Requesting NC_038612 genes ...
# > Requesting NC_014068 genes ...
# > Requesting NC_006273 genes ...
# > Requesting NC_038418 genes ...
# > Requesting NC_038360 genes ...
# > Requesting NC_007026 genes ...
# > Requesting NC_024888 genes ...
# > Requesting NC_013035 genes ...
# > Requesting NC_038282 genes ...
# > Requesting NC_014185 genes ...
# > Requesting NC_038352 genes ...
# > Requesting NC_055340 genes ...
# > Requesting NC_035758 genes ...
# > Requesting NC_001591 genes ...
# > Requesting NC_038414 genes ...
# > Requesting NC_039086 genes ...
# > Requesting NC_006435 genes ...
# > Requesting NC_035469 genes ...
# > Requesting NC_001576 genes ...
# > Requesting NC_034254 genes ...
# > Requesting NC_030447 genes ...
# > Requesting NC_038606 genes ...
# > Requesting NC_038413 genes ...
# > Requesting NC_038392 genes ...
# > Requesting NC_010329 genes ...
# > Requesting NC_012801 genes ...
# > Requesting NC_023984 genes ...
# > Requesting NC_034263 genes ...
# > Requesting NC_024472 genes ...
# > Requesting NC_014469 genes ...
# > Requesting NC_014095 genes ...
# > Requesting NC_035474 genes ...
# > Requesting NC_001611 genes ...
# > Requesting NC_038436 genes ...
# > Requesting NC_014097 genes ...
# > Requesting NC_025114 genes ...
# > Requesting NC_016157 genes ...
# > Requesting NC_014406 genes ...
# > Requesting NC_023891 genes ...
# > Requesting NC_038594 genes ...
# > Requesting NC_038727 genes ...
# > Requesting NC_038914 genes ...
# > Requesting NC_039063 genes ...
# > Requesting NC_014080 genes ...
# > Requesting NC_009238 genes ...
# > Requesting NC_026169 genes ...
# > Requesting NC_038354 genes ...
# > Requesting NC_027528 genes ...
# > Requesting NC_040805 genes ...
# > Requesting NC_030297 genes ...
# > Requesting NC_038523 genes ...
# > Requesting NC_033781 genes ...
# > Requesting NC_026252 genes ...
# > Requesting NC_008189 genes ...
# > Requesting NC_038726 genes ...
# > Requesting NC_004295 genes ...
# > Requesting NC_034487 genes ...
# > Requesting NC_038603 genes ...
# > Requesting NC_028125 genes ...
# > Requesting NC_035212 genes ...
# > Requesting NC_014081 genes ...
# > Requesting NC_040806 genes ...
# > Requesting NC_022518 genes ...
# > Requesting NC_038337 genes ...
# > Requesting NC_038358 genes ...
# > Requesting NC_001691 genes ...
# > Requesting NC_034616 genes ...
# > Requesting NC_014956 genes ...
# > Requesting NC_015150 genes ...
# > Requesting NC_032682 genes ...
# > Requesting NC_038611 genes ...
# > Requesting NC_019028 genes ...
# > Requesting NC_038497 genes ...
# > Requesting NC_040804 genes ...
# > Requesting NC_038412 genes ...
# > Requesting NC_038361 genes ...
# > Requesting NC_001583 genes ...
# > Requesting NC_022789 genes ...
# > Requesting NC_001693 genes ...
# > Requesting NC_012798 genes ...
# > Requesting NC_001593 genes ...
# > Requesting NC_011800 genes ...
# > Requesting NC_025726 genes ...
# > Requesting NC_025961 genes ...
# > Requesting NC_006313 genes ...
# > Requesting NC_001458 genes ...
# > Requesting NC_038599 genes ...
# > Requesting NC_004500 genes ...
# > Requesting NC_038522 genes ...
# > Requesting NC_021568 genes ...
# > Requesting NC_034256 genes ...
# > Requesting NC_038347 genes ...
# > Requesting NC_019027 genes ...
# > Requesting NC_001457 genes ...
# > Requesting NC_001587 genes ...
# > Requesting NC_038345 genes ...
# > Requesting NC_034255 genes ...
# > Requesting NC_038426 genes ...
# > Requesting NC_014083 genes ...
# > Requesting NC_014089 genes ...
# > Requesting NC_014407 genes ...
# > Requesting NC_028459 genes ...
# > Requesting NC_034262 genes ...
# > Requesting NC_039062 genes ...
# > Requesting NC_006577 genes ...
# > Requesting NC_038598 genes ...
# > Requesting NC_026946 genes ...
# > Requesting NC_055329 genes ...

# %%
email = "erikishere3@gmail.com"
# accession = "NC_001693"
accession = "NC_001348"
buffer = 0.5


old_stdout = sys.stdout

# creating a container storing stdout
gene_result = StringIO()
sys.stdout = gene_result

# calling ncbi gene database
c = entrezpy.conduit.Conduit(email)
fetch_genes = c.new_pipeline()
sid = fetch_genes.add_search(
    {
        "db": "gene",
        "term": f"{accession}",
        "rettype": "count",
        "datetype": "pdat",
    }
)
fid = fetch_genes.add_fetch(
    {"retmax": 10, "retmode": "text", "rettype": "fasta"}, dependency=sid
)
c.run(fetch_genes)
sleep(buffer)

# store the string from the stdout into variable
gene_conts = gene_result.getvalue()

# now redirect back stdout to screen
sys.stdout = old_stdout

print(gene_conts)

# parsing gene response contents
# gene_info = _parse_ncbi_genes_response(gene_conts)
# Out:
# 1. ORF68
# envelope glycoprotein E [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp69
# Other Designations: envelope glycoprotein E
# Annotation:  NC_001348.1 (115808..117721)
# ID: 1487709
#
# 2. ORF61
# ubiquitin E3 ligase ICP0 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp62
# Other Designations: ubiquitin E3 ligase ICP0
# Annotation:  NC_001348.1 (103001..104485, complement)
# ID: 1487698
#
# 3. ORF9
# tegument protein VP22 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp11
# Other Designations: tegument protein VP22
# Annotation:  NC_001348.1 (11009..11964)
# ID: 1487674
#
# 4. ORF31
# envelope glycoprotein B [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp33
# Other Designations: envelope glycoprotein B
# Annotation:  NC_001348.1 (56819..59648)
# ID: 1487662
#
# 5. ORF54
# capsid portal protein [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp55
# Other Designations: capsid portal protein
# Annotation:  NC_001348.1 (92850..95984, complement)
# ID: 1487723
#
# 6. ORF67
# envelope glycoprotein I [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp68
# Other Designations: envelope glycoprotein I
# Annotation:  NC_001348.1 (114496..115592)
# ID: 1487689
#
# 7. ORF62
# transcriptional regulator ICP4 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp72
# Other Designations: transcriptional regulator ICP4
# Annotation:  NC_001348.1 (120764..124756)
# ID: 1487695
#
# 8. ORF63
# regulatory protein ICP22 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp71
# Other Designations: regulatory protein ICP22
# Annotation:  NC_001348.1 (118466..119316, complement)
# ID: 1487711
#
# 9. ORF47
# tegument serine/threonine protein kinase [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp48
# Other Designations: tegument serine/threonine protein kinase
# Annotation:  NC_001348.1 (83168..86504)
# ID: 1487678
#
# 10. ORF36
# thymidine kinase [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp38
# Other Designations: thymidine kinase
# Annotation:  NC_001348.1 (64364..65885)
# ID: 1487667
#
# 11. ORF66
# serine/threonine protein kinase US3 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp67
# Other Designations: serine/threonine protein kinase US3
# Annotation:  NC_001348.1 (113037..114241)
# ID: 1487703
#
# 12. ORF7
# tegument protein UL51 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp08
# Other Designations: tegument protein UL51
# Annotation:  NC_001348.1 (8607..9399)
# ID: 1487677
#
# 13. ORF25
# DNA packaging protein UL33 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp27
# Other Designations: DNA packaging protein UL33
# Annotation:  NC_001348.1 (44131..44618, complement)
# ID: 1487665
#
# 14. ORF50
# envelope glycoprotein M [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp51
# Other Designations: envelope glycoprotein M
# Annotation:  NC_001348.1 (86541..87882, complement)
# ID: 1487658
#
# 15. ORF23
# small capsid protein [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp25
# Other Designations: small capsid protein
# Annotation:  NC_001348.1 (42426..43138, complement)
# ID: 1487705
#
# 16. ORF0
# membrane protein UL56 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp01
# Other Designations: membrane protein UL56
# Annotation:  NC_001348.1 (173..1060)
# ID: 1487696
#
# 17. ORF28
# DNA polymerase catalytic subunit [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp30
# Other Designations: DNA polymerase catalytic subunit
# Annotation:  NC_001348.1 (47031..50636, complement)
# ID: 1487712
#
# 18. ORF37
# envelope glycoprotein H [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp39
# Other Designations: envelope glycoprotein H
# Annotation:  NC_001348.1 (66074..68616)
# ID: 1487668
#
# 19. ORF62
# transcriptional regulator ICP4 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp63
# Other Designations: transcriptional regulator ICP4
# Annotation:  NC_001348.1 (105141..109133, complement)
# ID: 1487699
#
# 20. ORF29
# single-stranded DNA-binding protein [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp31
# Other Designations: single-stranded DNA-binding protein
# Annotation:  NC_001348.1 (50857..54523)
# ID: 1487713
#
# 21. ORF60
# envelope glycoprotein L [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp61
# Other Designations: envelope glycoprotein L
# Annotation:  NC_001348.1 (99387..101649, complement)
# ID: 1487692
#
# 22. ORF58
# nuclear protein UL3 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp59
# Other Designations: nuclear protein UL3
# Annotation:  NC_001348.1 (99387..100272, complement)
# ID: 1487690
#
# 23. ORF48
# deoxyribonuclease [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp49
# Other Designations: deoxyribonuclease
# Annotation:  NC_001348.1 (84667..86504)
# ID: 1487679
#
# 24. ORF10
# transactivating tegument protein VP16 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp12
# Other Designations: transactivating tegument protein VP16
# Annotation:  NC_001348.1 (12160..13421)
# ID: 1487675
#
# 25. ORF30
# DNA packaging terminase subunit 2 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp32
# Other Designations: DNA packaging terminase subunit 2
# Annotation:  NC_001348.1 (54651..59648)
# ID: 1487661
#
# 26. ORF14
# envelope glycoprotein C [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp16
# Other Designations: envelope glycoprotein C
# Annotation:  NC_001348.1 (19342..21113, complement)
# ID: 1487660
#
# 27. ORF12
# tegument protein VP11/12 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp14
# Other Designations: tegument protein VP11/12
# Annotation:  NC_001348.1 (16214..19396)
# ID: 1487655
#
# 28. ORF11
# tegument protein VP13/14 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp13
# Other Designations: tegument protein VP13/14
# Annotation:  NC_001348.1 (13590..16122)
# ID: 1487654
#
# 29. ORF4
# multifunctional expression regulator [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp05
# Other Designations: multifunctional expression regulator
# Annotation:  NC_001348.1 (2777..4141, complement)
# ID: 1487672
#
# 30. ORF9A
# envelope glycoprotein N [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp10.5
# Other Designations: envelope glycoprotein N
# Annotation:  NC_001348.1 (10642..11964)
# ID: 4711773
#
# 31. ORF53
# tegument protein UL7 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp54
# Other Designations: tegument protein UL7
# Annotation:  NC_001348.1 (92850..93850, complement)
# ID: 1487722
#
# 32. ORF52
# helicase-primase subunit [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp53
# Other Designations: helicase-primase subunit
# Annotation:  NC_001348.1 (90493..92846)
# ID: 1487721
#
# 33. ORF46
# tegument protein UL14 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp47
# Other Designations: tegument protein UL14
# Annotation:  NC_001348.1 (82719..86504)
# ID: 1487720
#
# 34. ORF42
# DNA packaging terminase subunit 1 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp44
# Other Designations: DNA packaging terminase subunit 1
# Annotation:  NC_001348.1 (76850..82593, complement)
# ID: 1487719
#
# 35. ORF44
# tegument protein UL16 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp46
# Other Designations: tegument protein UL16
# Annotation:  NC_001348.1 (80360..81514)
# ID: 1487718
#
# 36. ORF33
# capsid maturation protease [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp35
# Other Designations: capsid maturation protease
# Annotation:  NC_001348.1 (60309..62138, complement)
# ID: 1487717
#
# 37. ORF19
# ribonucleotide reductase subunit 1 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp21
# Other Designations: ribonucleotide reductase subunit 1
# Annotation:  NC_001348.1 (25550..28845, complement)
# ID: 1487716
#
# 38. ORF18
# ribonucleotide reductase subunit 2 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp20
# Other Designations: ribonucleotide reductase subunit 2
# Annotation:  NC_001348.1 (25550..26493, complement)
# ID: 1487715
#
# 39. ORF17
# tegument host shutoff protein [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp19
# Other Designations: tegument host shutoff protein
# Annotation:  NC_001348.1 (24149..25517)
# ID: 1487714
#
# 40. ORF64
# virion protein US10 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp70
# Other Designations: virion protein US10
# Annotation:  NC_001348.1 (117756..118332, complement)
# ID: 1487710
#
# 41. ORF40
# major capsid protein [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp42
# Other Designations: major capsid protein
# Annotation:  NC_001348.1 (71540..75763)
# ID: 1487708
#
# 42. ORF39
# envelope protein UL20 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp41
# Other Designations: envelope protein UL20
# Annotation:  NC_001348.1 (70687..71369)
# ID: 1487707
#
# 43. ORF38
# tegument protein UL21 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp40
# Other Designations: tegument protein UL21
# Annotation:  NC_001348.1 (68647..70293, complement)
# ID: 1487706
#
# 44. ORF22
# large tegument protein [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp24
# Other Designations: large tegument protein
# Annotation:  NC_001348.1 (34083..42390)
# ID: 1487704
#
# 45. ORF65
# membrane protein US9 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp66
# Other Designations: membrane protein US9
# Annotation:  NC_001348.1 (112176..112640, complement)
# ID: 1487702
#
# 46. ORF64
# virion protein US10 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp65
# Other Designations: virion protein US10
# Annotation:  NC_001348.1 (111565..112141)
# ID: 1487701
#
# 47. ORF63
# regulatory protein ICP22 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp64
# Other Designations: regulatory protein ICP22
# Annotation:  NC_001348.1 (110581..111431)
# ID: 1487700
#
# 48. ORF26
# DNA packaging protein UL32 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp28
# Other Designations: DNA packaging protein UL32
# Annotation:  NC_001348.1 (44506..47243)
# ID: 1487694
#
# 49. ORF24
# nuclear egress membrane protein [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp26
# Other Designations: nuclear egress membrane protein
# Annotation:  NC_001348.1 (43211..44021, complement)
# ID: 1487693
#
# 50. ORF59
# uracil-DNA glycosylase [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp60
# Other Designations: uracil-DNA glycosylase
# Annotation:  NC_001348.1 (99387..101219, complement)
# ID: 1487691
#
# 51. ORF35
# nuclear protein UL24 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp37
# Other Designations: nuclear protein UL24
# Annotation:  NC_001348.1 (60309..64753, complement)
# ID: 1487688
#
# 52. ORF34
# DNA packaging tegument protein UL25 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp36
# Other Designations: DNA packaging tegument protein UL25
# Annotation:  NC_001348.1 (60309..63910, complement)
# ID: 1487687
#
# 53. ORF21
# tegument protein UL37 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp23
# Other Designations: tegument protein UL37
# Annotation:  NC_001348.1 (30759..33905)
# ID: 1487686
#
# 54. ORF20
# capsid triplex subunit 1 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp22
# Other Designations: capsid triplex subunit 1
# Annotation:  NC_001348.1 (29005..30475, complement)
# ID: 1487685
#
# 55. ORF57
# protein V57 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp58
# Other Designations: protein V57
# Annotation:  NC_001348.1 (99387..99626, complement)
# ID: 1487684
#
# 56. ORF56
# nuclear protein UL4 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp57
# Other Designations: nuclear protein UL4
# Annotation:  NC_001348.1 (98712..99358)
# ID: 1487683
#
# 57. ORF55
# helicase-primase helicase subunit [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp56
# Other Designations: helicase-primase helicase subunit
# Annotation:  NC_001348.1 (95996..99358)
# ID: 1487682
#
# 58. ORF3
# nuclear protein UL55 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp04
# Other Designations: nuclear protein UL55
# Annotation:  NC_001348.1 (1890..2447, complement)
# ID: 1487681
#
# 59. ORF2
# myristylated tegument protein CIRC [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp03
# Other Designations: myristylated tegument protein CIRC
# Annotation:  NC_001348.1 (1134..1862)
# ID: 1487680
#
# 60. ORF6
# helicase-primase primase subunit [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp07
# Other Designations: helicase-primase primase subunit
# Annotation:  NC_001348.1 (2777..8577, complement)
# ID: 1487676
#
#
# 61. ORF5
# envelope glycoprotein K [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp06
# Other Designations: envelope glycoprotein K
# Annotation:  NC_001348.1 (2777..5274, complement)
# ID: 1487673
#
# 62. ORF8
# deoxyuridine triphosphatase [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp09
# Other Designations: deoxyuridine triphosphatase
# Annotation:  NC_001348.1 (9426..10667, complement)
# ID: 1487671
#
# 63. ORF43
# DNA packaging tegument protein UL17 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp45
# Other Designations: DNA packaging tegument protein UL17
# Annotation:  NC_001348.1 (78170..80201)
# ID: 1487670
#
# 64. ORF41
# capsid triplex subunit 2 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp43
# Other Designations: capsid triplex subunit 2
# Annotation:  NC_001348.1 (75847..76812)
# ID: 1487669
#
# 65. ORF27
# nuclear egress lamina protein [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp29
# Other Designations: nuclear egress lamina protein
# Annotation:  NC_001348.1 (46190..47243)
# ID: 1487666
#
# 66. ORF32
# protein V32 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp34
# Other Designations: protein V32
# Annotation:  NC_001348.1 (59766..60213)
# ID: 1487663
#
# 67. ORF13
# thymidylate synthase [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp15
# Other Designations: thymidylate synthase
# Annotation:  NC_001348.1 (18441..19396)
# ID: 1487659
#
# 68. ORF51
# DNA replication origin-binding helicase [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp52
# Other Designations: DNA replication origin-binding helicase
# Annotation:  NC_001348.1 (87881..92846)
# ID: 1487657
#
# 69. ORF49
# myristylated tegument protein [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp50
# Other Designations: myristylated tegument protein
# Annotation:  NC_001348.1 (86226..86504)
# ID: 1487656
#
# 70. ORF16
# DNA polymerase processivity subunit [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp18
# Other Designations: DNA polymerase processivity subunit
# Annotation:  NC_001348.1 (21244..23794, complement)
# ID: 1487653
#
# 71. ORF33.5
# capsid scaffold protein [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp35.5
# Other Designations: capsid scaffold protein
# Annotation:  NC_001348.1 (60309..61229, complement)
# ID: 4711772
#
# 72. ORF1
# membrane protein V1 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp02
# Other Designations: membrane protein V1
# Annotation:  NC_001348.1 (588..915, complement)
# ID: 1487664
#
# 73. ORF15
# envelope protein UL43 [Human alphaherpesvirus 3 (Varicella-zoster virus)]
# Other Aliases: HHV3_gp17
# Other Designations: envelope protein UL43
# Annotation:  NC_001348.1 (21244..22478, complement)
# ID: 1487652
#
# 74. HHV3gp10
# Predicted by GeneMark [Human herpesvirus 3]
# Other Aliases: HHV3gp10
# Other Designations: Predicted by GeneMark; membrane protein
# Annotation:  NC_001348.1 (10678..10905)
# This record was discontinued.
# ID: 1487697

# %%
split_contents = gene_conts.splitlines()
split_contents = [line_data for line_data in split_contents if len(line_data) != 0]
chunked_contents = [
    split_contents[i : i + 6] for i in range(0, len(split_contents), 6)
]

# %%
for chunk in chunked_contents:
    
    # removing discontinued genes
    if "discontinued" in " ".join(chunk):
            continue
    # gene name  
    name = chunk[0].split(".")[-1].strip()

    # iterating through contents
    for line in chunk[1:]:
        if line.startswith("Annotation"):
            if "complement" in line:
                annotation = (
                    line.split(":")[-1]
                    .replace("(", "")
                    .replace(")", "")
                    .split()[1]
                    .replace(",", "")
                    .split("..")
                )
            else:
                annotation = (
                    line.split()[-1]
                    .replace("(", "")
                    .replace(")", "")
                    .replace(",", "")
                    .split("..")
                )
            annotation_range = tuple([int(i) for i in annotation])
        
        elif line.startswith("Other Designations:"):
            description = line.split(":")[-1].strip()

        elif line.startswith("ID"):
            gene_id = line.split()[-1].strip()

# %%
split_contents = gene_conts.splitlines()
split_contents = [line_data for line_data in split_contents if len(line_data) != 0]
chunked_contents = [
    split_contents[i : i + 6] for i in range(0, len(split_contents), 6)
]

# TODO: need to redesign annotatation extraction is not general
gene_dict = defaultdict(None)
for idx, chunked_content in enumerate(chunked_contents):
    subdict = {}
    if "discontinued" in " ".join(chunked_content):
        continue

    if len(chunked_content) != 6:
        continue


    name = chunked_content[0].split(".")[-1].strip()
    gene_id = chunked_content[-1].split(":")[-1].strip()
    for line in chunked_content:

        # iterating through contents
        if line.startswith("Annotation"):
            if "complement" in line:
                annotation = (
                    line.split(":")[-1]
                    .replace("(", "")
                    .replace(")", "")
                    .split()[1]
                    .replace(",", "")
                    .split("..")
                )
            else:
                annotation = (
                    line.split()[-1]
                    .replace("(", "")
                    .replace(")", "")
                    .replace(",", "")
                    .split("..")
                )
            annotation_range = tuple([int(i) for i in annotation])
            subdict["annotation"] = annotation_range

        elif line.startswith("Other Designations:"):
            description = line.split(":")[-1].strip()
            subdict["name"] = f"{name}: {description}"


    gene_dict[gene_id] = subdict

# %%
clean_all_genes()

# %%
all_accessions[:5]
gene_dict
# Out:
# defaultdict(None,
#             {'1487709': {'name': 'ORF68: envelope glycoprotein E',
#               'annotation': (115808, 117721)},
#              '1487698': {'name': 'ORF61: ubiquitin E3 ligase ICP0',
#               'annotation': (103001, 104485)},
#              '1487674': {'name': 'ORF9: tegument protein VP22',
#               'annotation': (11009, 11964)},
#              '1487662': {'name': 'ORF31: envelope glycoprotein B',
#               'annotation': (56819, 59648)},
#              '1487723': {'name': 'ORF54: capsid portal protein',
#               'annotation': (92850, 95984)},
#              '1487689': {'name': 'ORF67: envelope glycoprotein I',
#               'annotation': (114496, 115592)},
#              '1487695': {'name': 'ORF62: transcriptional regulator ICP4',
#               'annotation': (120764, 124756)},
#              '1487711': {'name': 'ORF63: regulatory protein ICP22',
#               'annotation': (118466, 119316)},
#              '1487678': {'name': 'ORF47: tegument serine/threonine protein kinase',
#               'annotation': (83168, 86504)},
#              '1487667': {'name': 'ORF36: thymidine kinase',
#               'annotation': (64364, 65885)},
#              '1487703': {'name': 'ORF66: serine/threonine protein kinase US3',
#               'annotation': (113037, 114241)},
#              '1487677': {'name': 'ORF7: tegument protein UL51',
#               'annotation': (8607, 9399)},
#              '1487665': {'name': 'ORF25: DNA packaging protein UL33',
#               'annotation': (44131, 44618)},
#              '1487658': {'name': 'ORF50: envelope glycoprotein M',
#               'annotation': (86541, 87882)},
#              '1487705': {'name': 'ORF23: small capsid protein',
#               'annotation': (42426, 43138)},
#              '1487696': {'name': 'ORF0: membrane protein UL56',
#               'annotation': (173, 1060)},
#              '1487712': {'name': 'ORF28: DNA polymerase catalytic subunit',
#               'annotation': (47031, 50636)},
#              '1487668': {'name': 'ORF37: envelope glycoprotein H',
#               'annotation': (66074, 68616)},
#              '1487699': {'name': 'ORF62: transcriptional regulator ICP4',
#               'annotation': (105141, 109133)},
#              '1487713': {'name': 'ORF29: single-stranded DNA-binding protein',
#               'annotation': (50857, 54523)},
#              '1487692': {'name': 'ORF60: envelope glycoprotein L',
#               'annotation': (99387, 101649)},
#              '1487690': {'name': 'ORF58: nuclear protein UL3',
#               'annotation': (99387, 100272)},
#              '1487679': {'name': 'ORF48: deoxyribonuclease',
#               'annotation': (84667, 86504)},
#              '1487675': {'name': 'ORF10: transactivating tegument protein VP16',
#               'annotation': (12160, 13421)},
#              '1487661': {'name': 'ORF30: DNA packaging terminase subunit 2',
#               'annotation': (54651, 59648)},
#              '1487660': {'name': 'ORF14: envelope glycoprotein C',
#               'annotation': (19342, 21113)},
#              '1487655': {'name': 'ORF12: tegument protein VP11/12',
#               'annotation': (16214, 19396)},
#              '1487654': {'name': 'ORF11: tegument protein VP13/14',
#               'annotation': (13590, 16122)},
#              '1487672': {'name': 'ORF4: multifunctional expression regulator',
#               'annotation': (2777, 4141)},
#              '4711773': {'name': 'ORF9A: envelope glycoprotein N',
#               'annotation': (10642, 11964)},
#              '1487722': {'name': 'ORF53: tegument protein UL7',
#               'annotation': (92850, 93850)},
#              '1487721': {'name': 'ORF52: helicase-primase subunit',
#               'annotation': (90493, 92846)},
#              '1487720': {'name': 'ORF46: tegument protein UL14',
#               'annotation': (82719, 86504)},
#              '1487719': {'name': 'ORF42: DNA packaging terminase subunit 1',
#               'annotation': (76850, 82593)},
#              '1487718': {'name': 'ORF44: tegument protein UL16',
#               'annotation': (80360, 81514)},
#              '1487717': {'name': 'ORF33: capsid maturation protease',
#               'annotation': (60309, 62138)},
#              '1487716': {'name': 'ORF19: ribonucleotide reductase subunit 1',
#               'annotation': (25550, 28845)},
#              '1487715': {'name': 'ORF18: ribonucleotide reductase subunit 2',
#               'annotation': (25550, 26493)},
#              '1487714': {'name': 'ORF17: tegument host shutoff protein',
#               'annotation': (24149, 25517)},
#              '1487710': {'name': 'ORF64: virion protein US10',
#               'annotation': (117756, 118332)},
#              '1487708': {'name': 'ORF40: major capsid protein',
#               'annotation': (71540, 75763)},
#              '1487707': {'name': 'ORF39: envelope protein UL20',
#               'annotation': (70687, 71369)},
#              '1487706': {'name': 'ORF38: tegument protein UL21',
#               'annotation': (68647, 70293)},
#              '1487704': {'name': 'ORF22: large tegument protein',
#               'annotation': (34083, 42390)},
#              '1487702': {'name': 'ORF65: membrane protein US9',
#               'annotation': (112176, 112640)},
#              '1487701': {'name': 'ORF64: virion protein US10',
#               'annotation': (111565, 112141)},
#              '1487700': {'name': 'ORF63: regulatory protein ICP22',
#               'annotation': (110581, 111431)},
#              '1487694': {'name': 'ORF26: DNA packaging protein UL32',
#               'annotation': (44506, 47243)},
#              '1487693': {'name': 'ORF24: nuclear egress membrane protein',
#               'annotation': (43211, 44021)},
#              '1487691': {'name': 'ORF59: uracil-DNA glycosylase',
#               'annotation': (99387, 101219)},
#              '1487688': {'name': 'ORF35: nuclear protein UL24',
#               'annotation': (60309, 64753)},
#              '1487687': {'name': 'ORF34: DNA packaging tegument protein UL25',
#               'annotation': (60309, 63910)},
#              '1487686': {'name': 'ORF21: tegument protein UL37',
#               'annotation': (30759, 33905)},
#              '1487685': {'name': 'ORF20: capsid triplex subunit 1',
#               'annotation': (29005, 30475)},
#              '1487684': {'name': 'ORF57: protein V57',
#               'annotation': (99387, 99626)},
#              '1487683': {'name': 'ORF56: nuclear protein UL4',
#               'annotation': (98712, 99358)},
#              '1487682': {'name': 'ORF55: helicase-primase helicase subunit',
#               'annotation': (95996, 99358)},
#              '1487681': {'name': 'ORF3: nuclear protein UL55',
#               'annotation': (1890, 2447)},
#              '1487680': {'name': 'ORF2: myristylated tegument protein CIRC',
#               'annotation': (1134, 1862)},
#              '1487676': {'name': 'ORF6: helicase-primase primase subunit',
#               'annotation': (2777, 8577)},
#              '1487673': {'name': 'ORF5: envelope glycoprotein K',
#               'annotation': (2777, 5274)},
#              '1487671': {'name': 'ORF8: deoxyuridine triphosphatase',
#               'annotation': (9426, 10667)},
#              '1487670': {'name': 'ORF43: DNA packaging tegument protein UL17',
#               'annotation': (78170, 80201)},
#              '1487669': {'name': 'ORF41: capsid triplex subunit 2',
#               'annotation': (75847, 76812)},
#              '1487666': {'name': 'ORF27: nuclear egress lamina protein',
#               'annotation': (46190, 47243)},
#              '1487663': {'name': 'ORF32: protein V32',
#               'annotation': (59766, 60213)},
#              '1487659': {'name': 'ORF13: thymidylate synthase',
#               'annotation': (18441, 19396)},
#              '1487657': {'name': 'ORF51: DNA replication origin-binding helicase',
#               'annotation': (87881, 92846)},
#              '1487656': {'name': 'ORF49: myristylated tegument protein',
#               'annotation': (86226, 86504)},
#              '1487653': {'name': 'ORF16: DNA polymerase processivity subunit',
#               'annotation': (21244, 23794)},
#              '4711772': {'name': '5: capsid scaffold protein',
#               'annotation': (60309, 61229)},
#              '1487664': {'name': 'ORF1: membrane protein V1',
#               'annotation': (588, 915)},
#              '1487652': {'name': 'ORF15: envelope protein UL43',
#               'annotation': (21244, 22478)}})
