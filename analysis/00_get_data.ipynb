# %%
import sys
from pathlib import Path
import requests
import pandas as pd


# vseek imports
sys.path.append("../")
import vseek.common.vseek_paths as vsp
from vseek.apis.dbat_vir_db import collect_dbatvir_data
from vseek.apis.ncbi import get_all_viral_accessions

# %%
#NOTE: the data has been downloaded already
# collect the data from the VBatDB
batvir_df = collect_dbatvir_data()
batvir_df.head()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/home/axiomcura/.wdm/drivers/chromedriver/linux64/102.0.5005.61/chromedriver] found in cache
# Entering Bat-associated Virus database
# Connected to DBatVir!
# ...
# Downloading: Retro-transcribing-viruses data...
# Downloading: dsDNA-viruses-noRNA-stage data...
# Downloading: dsRNA-virus data...
# Downloading: ssDNA-virus data...
# Downloading: ssRNA-negative-strand-viruses data...
# Downloading: ssRNA-positive-strand-viruses-noDNA-Stage data...
# Download complete! Closing portal...
# Merging downloaded data into one .csv file
# 0                                Viruses  Viral family  \
# 1        Bat adeno-associated virus 07YN  Parvoviridae
# 2        Bat adeno-associated virus 09YN  Parvoviridae
# 3  Bat adeno-associated virus 1003-HB-Mr  Parvoviridae
# 4  Bat adeno-associated virus 1008-HB-Mr  Parvoviridae
# ...

# %%
#NOTE: the data has been downloaded already
# downloading ncbi accession list
ncbi_acc_df = get_all_viral_accessions()
ncbi_acc_df.head()
# Out:
#   Representative  Neighbor               Host  \
# 0      NC_003663  HQ420896  human,vertebrates
# 1      NC_003663  KY463519  human,vertebrates
# 2      NC_003663  HQ420897  human,vertebrates
# 3      NC_003663  MK035759  human,vertebrates
# 4      NC_003663  KY569019  human,vertebrates
#
#                         Selected lineage Taxonomy name Segment name
# 0  Poxviridae,Orthopoxvirus,Cowpox virus  Cowpox virus      segment
# 1  Poxviridae,Orthopoxvirus,Cowpox virus  Cowpox virus      segment
# 2  Poxviridae,Orthopoxvirus,Cowpox virus  Cowpox virus      segment
# 3  Poxviridae,Orthopoxvirus,Cowpox virus  Cowpox virus      segment
# 4  Poxviridae,Orthopoxvirus,Cowpox virus  Cowpox virus      segment

# %%
# filter viral family that are only found in bats
viral_fam = batvir_df["Viral family"].dropna().unique().tolist()

sel_dfs = []
for v_fam in viral_fam:
    sel_df = ncbi_acc_df.loc[ncbi_acc_df["Selected lineage"].str.contains(v_fam)]
    if len(sel_df) == 0:
        continue
    sel_dfs.append(sel_df)

sel_dfs = pd.concat(sel_dfs, axis=0)

# %%
# downloading fastq files
sel_dfs.to_csv("test.csv")

# %%
viral_fam
# Out:
# ['Parvoviridae',
#  'Circoviridae',
#  'Anelloviridae',
#  'Genomoviridae',
#  'Smacoviridae',
#  'Hepadnaviridae',
#  'Retroviridae',
#  'Reoviridae',
#  'Picobirnaviridae',
#  'Adenoviridae',
#  'Poxviridae',
#  'Herpesviridae',
#  'Polyomaviridae',
#  'Papillomaviridae',
#  'Rhabdoviridae',
#  'Paramyxoviridae',
#  'Hantaviridae',
#  'Filoviridae',
#  'Nairoviridae',
#  'Orthomyxoviridae',
#  'Peribunyaviridae',
#  'Phenuiviridae',
#  'Bornaviridae',
#  'Arenaviridae']

# %%
df = get_all_viral_accessions()

# %%
df
# Out:
#        Representative  Neighbor               Host  \
# 0           NC_003663  HQ420896  human,vertebrates
# 1           NC_003663  KY463519  human,vertebrates
# 2           NC_003663  HQ420897  human,vertebrates
# 3           NC_003663  MK035759  human,vertebrates
# 4           NC_003663  KY569019  human,vertebrates
# ...               ...       ...                ...
# 255061      NC_062761  MZ334528                NaN
# 255062      NC_062762  MZ334526                NaN
# 255063      NC_062763  MZ334501                NaN
# 255064      NC_060136  OK040786                NaN
# 255065      NC_054649  MT768060                NaN
#
#                                          Selected lineage  \
# 0                   Poxviridae,Orthopoxvirus,Cowpox virus
# 1                   Poxviridae,Orthopoxvirus,Cowpox virus
# 2                   Poxviridae,Orthopoxvirus,Cowpox virus
# 3                   Poxviridae,Orthopoxvirus,Cowpox virus
# ...

# %%
batvir_df = collect_dbatvir_data()
batvir_df
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/home/axiomcura/.wdm/drivers/chromedriver/linux64/102.0.5005.61/chromedriver] found in cache
# Entering Bat-associated Virus database
# Connected to DBatVir!
# ...
# Downloading: Retro-transcribing-viruses data...
# Downloading: dsDNA-viruses-noRNA-stage data...
# Downloading: dsRNA-virus data...
# Downloading: ssDNA-virus data...
# Downloading: ssRNA-negative-strand-viruses data...
# Downloading: ssRNA-positive-strand-viruses-noDNA-Stage data...
# Download complete! Closing portal...
# Merging downloaded data into one .csv file
# 0                                      Viruses   Viral family  \
# 1              Bat adeno-associated virus 07YN   Parvoviridae
# 2              Bat adeno-associated virus 09YN   Parvoviridae
# 3        Bat adeno-associated virus 1003-HB-Mr   Parvoviridae
# ...

# %%
batvir_df
# Out:
#                                        Viruses   Viral family  \
# 0              Bat adeno-associated virus 07YN   Parvoviridae
# 1              Bat adeno-associated virus 09YN   Parvoviridae
# 2        Bat adeno-associated virus 1003-HB-Mr   Parvoviridae
# 3        Bat adeno-associated virus 1008-HB-Mr   Parvoviridae
# 4        Bat adeno-associated virus 1019-HB-Rs   Parvoviridae
# ...                                        ...            ...
# 6848                   Bombali ebolavirus Z153    Filoviridae
# 6849                   Bombali ebolavirus Z178    Filoviridae
# 6850             Rabies lyssavirus Zhongshan77  Rhabdoviridae
# 6851           Zwiesel bat banyangvirus ZV2011  Phenuiviridae
# 6852  Table saved from ZOVER [Fri Jun 10 2022]            NaN
#
#                      From Bat              Bat diet type        Bat family  \
# 0     unclassified Chiroptera                        NaN               NaN
# ...

# %%
import glob

# %%
def _group_dfs(data_path: str) -> list:
    """Places all pandas data frames into a list

    Parameters
    ----------
    data_path : str
        path containing all DBatVir data

    Returns
    -------
    list
        list of pd.DataFrames of DBatVir data
    """
    print("Merging downloaded data into one .csv file")

    # check if all the files are downloaded (there should be a total of 6)
    # -- if not all were downloaded, it will print a warning
    all_files = glob.glob(f"{data_path}/*")
    if not len(all_files) == 6:
        print("WARNING: not all files were downloaded")

    # now for the pandas part (merging all downloaded data into a giant .csv file)
    # -- creating all
    df_list = []
    for data_file in all_files:
        df = pd.read_excel(data_file)

        # editing header and reformating dataset
        header = df.iloc[0]
        df = df[1:]
        df.columns = header
        df_list.append(df)

    return df_list

# %%
dfs = _group_dfs("../db_test/")
# Out:
# Merging downloaded data into one .csv file

# %%
pd.concat(dfs, axis=0).to_csv("DBatVir_db.csv.gz", compression="gzip", index=False)
